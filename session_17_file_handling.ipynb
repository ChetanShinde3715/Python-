# %% [markdown]
# File Handling

# %%
*** Extensions of file  ***


file   ===== .txt
ejson file  ====== 
json file  ====== .json.csv (comma seperated value) , .pdf
yaml        ===== .yaml

=======================Encoded file=====================


word      =======  .doc and .docx
xml       ======= .xml
paequet   ======= .parquet
delta     ======   .delta
trecords  ======  .tfrecods (tf:tensorflow)
image     ======  .jpg or .png or .jpeg
video    ====== .mp4
audio    ======= .mp3

# %% [markdown]
# -------- In order to read the file ----------
#
# 1)  Where is file located : directory of the folder
# 2)  What is the file name : in that folder so many file will be available
# 3)  What is the file extension : type of the file.

# %% [markdown]
# ** Unicode error **
#
# - When ever we read the file it should be in quotes
# - If we have single slash only,then we will get unicode error
# - In order to avoid that, we need to provide that doulble slash
# - we can provide a letter 'r' without quotes at the begining of the file path

# %%
(r"D:\Study material\DemographicData.csv")
# Out:
# 'D:\\Study material\\DemographicData.csv'

# %% [markdown]
# ** Read the file **

# %%
# file path is used as variable of that file path

file_path  =  (r"D:\Study material\DemographicData.csv")

file = open(file_path)

print(file.read())
# Out:
# CountryName,CountryCode,BirthRate,InternetUsers,IncomeGroup
# Aruba,ABW,10.244,78.9,High income
# Afghanistan,AFG,35.253,5.9,Low income
# Angola,AGO,45.985,19.1,Upper middle income
# Albania,ALB,12.877,57.2,Upper middle income
# United Arab Emirates,ARE,11.044,88,High income
# Argentina,ARG,17.716,59.9,High income
# Armenia,ARM,13.308,41.9,Lower middle income
# Antigua and Barbuda,ATG,16.447,63.4,High income
# Australia,AUS,13.2,83,High income
# Austria,AUT,9.4,80.6188,High income
# Azerbaijan,AZE,18.3,58.7,Upper middle income
# Burundi,BDI,44.151,1.3,Low income
# Belgium,BEL,11.2,82.1702,High income
# Benin,BEN,36.44,4.9,Low income
# Burkina Faso,BFA,40.551,9.1,Low income
# Bangladesh,BGD,20.142,6.63,Lower middle income
# Bulgaria,BGR,9.2,53.0615,Upper middle income
# Bahrain,BHR,15.04,90.0000397,High income
# "Bahamas, The",BHS,15.339,72,High income
# Bosnia and Herzegovina,BIH,9.062,57.79,Upper middle income
# Belarus,BLR,12.5,54.17,Upper middle income
# ...

# %% [markdown]
# 1) denied permission error :
#
#      - First you are opening the file in the laptop
#      - Then you are reading the file in python
#      - Then you will get persimssion errro
#      - First you need to close that file then you need to read in python.
#
# 2) file not found error :
#
#      - Which means you are trying to read a file.
#      - That file is not available in that location.
#      - First go to that directory and check it file is there or not
#      - Check the seplling,check the spaces
#
# Whenever we read :
#
#     - file
#
#     - mode :
#         by default it is 'r '= read model
#         if you want to write it will apply 'w'
#
#     - encode :
#         encoding is used to avoid specail character
#         by default cp1252
#         if you want to avoid special charaters = 'utf-8-sig'

# %%
file_path  =  (r"D:\Study material\DemographicData.csv")

# 1)   file = open(file_path,mode='r',encoding='utf-8-sig')
     #print(file.read())
# 2)
with open(file_path) as file :
    
    data=file.read()
print(data)
# Out:
# CountryName,CountryCode,BirthRate,InternetUsers,IncomeGroup
# Aruba,ABW,10.244,78.9,High income
# Afghanistan,AFG,35.253,5.9,Low income
# Angola,AGO,45.985,19.1,Upper middle income
# Albania,ALB,12.877,57.2,Upper middle income
# United Arab Emirates,ARE,11.044,88,High income
# Argentina,ARG,17.716,59.9,High income
# Armenia,ARM,13.308,41.9,Lower middle income
# Antigua and Barbuda,ATG,16.447,63.4,High income
# Australia,AUS,13.2,83,High income
# Austria,AUT,9.4,80.6188,High income
# Azerbaijan,AZE,18.3,58.7,Upper middle income
# Burundi,BDI,44.151,1.3,Low income
# Belgium,BEL,11.2,82.1702,High income
# Benin,BEN,36.44,4.9,Low income
# Burkina Faso,BFA,40.551,9.1,Low income
# Bangladesh,BGD,20.142,6.63,Lower middle income
# Bulgaria,BGR,9.2,53.0615,Upper middle income
# Bahrain,BHR,15.04,90.0000397,High income
# "Bahamas, The",BHS,15.339,72,High income
# Bosnia and Herzegovina,BIH,9.062,57.79,Upper middle income
# Belarus,BLR,12.5,54.17,Upper middle income
# ...

# %% [markdown]
# -------------- Method 2 --------------------
#
# - We can read the file without using folder
# - because every directory is different
# - different laptop have different directory
# - Whenever we handover to ther client we should avoid
# - For that will keep the data file and python in same location

# %% [markdown]
# -------------- Method 3 ----------------------

# %%
# Q1) WAP to print first 10 line form the file

file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
count=0
for i in file :
    print(i)
    count+=1
    if count==10:
        break
# Out:
# CountryName,CountryCode,BirthRate,InternetUsers,IncomeGroup
#
# Aruba,ABW,10.244,78.9,High income
#
# Afghanistan,AFG,35.253,5.9,Low income
#
# Angola,AGO,45.985,19.1,Upper middle income
#
# Albania,ALB,12.877,57.2,Upper middle income
#
# United Arab Emirates,ARE,11.044,88,High income
#
# Argentina,ARG,17.716,59.9,High income
#
# Armenia,ARM,13.308,41.9,Lower middle income
#
# Antigua and Barbuda,ATG,16.447,63.4,High income
#
# Australia,AUS,13.2,83,High income

# %%
# Q2) WAP to print total number of lines in the file.

file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
count=0
for i in file :
    count+=1
print(count)
# Out:
# 196

# %% [markdown]
# ** Enumerate **
#
#     - Enumerate will give two values
#     - one is index value and another one is line
#     - enumerate is similar to zip

# %%
# use underscore whenever you don't want to use that variable 

pass : 

file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
count=0
for index,_ in enumerate(file) :
     pass

print(index)
# Out:
# 195

# %%
# Q3) Without counter find the number of lines 

file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
count=0
num_of_lines=[index for index,line in enumerate(file) ]
len(num_of_lines)
# Out:
# 196

# %%
# Q4) make every line in alignment

file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
for i in file:
    print(i.strip()) # If we want to make lines in alignment the we have method that is .strip()
# Out:
# CountryName,CountryCode,BirthRate,InternetUsers,IncomeGroup
# Aruba,ABW,10.244,78.9,High income
# Afghanistan,AFG,35.253,5.9,Low income
# Angola,AGO,45.985,19.1,Upper middle income
# Albania,ALB,12.877,57.2,Upper middle income
# United Arab Emirates,ARE,11.044,88,High income
# Argentina,ARG,17.716,59.9,High income
# Armenia,ARM,13.308,41.9,Lower middle income
# Antigua and Barbuda,ATG,16.447,63.4,High income
# Australia,AUS,13.2,83,High income
# Austria,AUT,9.4,80.6188,High income
# Azerbaijan,AZE,18.3,58.7,Upper middle income
# Burundi,BDI,44.151,1.3,Low income
# Belgium,BEL,11.2,82.1702,High income
# Benin,BEN,36.44,4.9,Low income
# Burkina Faso,BFA,40.551,9.1,Low income
# Bangladesh,BGD,20.142,6.63,Lower middle income
# Bulgaria,BGR,9.2,53.0615,Upper middle income
# Bahrain,BHR,15.04,90.0000397,High income
# "Bahamas, The",BHS,15.339,72,High income
# Bosnia and Herzegovina,BIH,9.062,57.79,Upper middle income
# Belarus,BLR,12.5,54.17,Upper middle income
# ...

# %%
file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
for i in file:
    print(i.lstrip()) # If we want to make lines in alignment the we have method that is .strip()
# Out:
# CountryName,CountryCode,BirthRate,InternetUsers,IncomeGroup
#
# Aruba,ABW,10.244,78.9,High income
#
# Afghanistan,AFG,35.253,5.9,Low income
#
# Angola,AGO,45.985,19.1,Upper middle income
#
# Albania,ALB,12.877,57.2,Upper middle income
#
# United Arab Emirates,ARE,11.044,88,High income
#
# Argentina,ARG,17.716,59.9,High income
#
# Armenia,ARM,13.308,41.9,Lower middle income
#
# Antigua and Barbuda,ATG,16.447,63.4,High income
#
# Australia,AUS,13.2,83,High income
#
# Austria,AUT,9.4,80.6188,High income
#
# Azerbaijan,AZE,18.3,58.7,Upper middle income
#
# Burundi,BDI,44.151,1.3,Low income
#
# Belgium,BEL,11.2,82.1702,High income
#
# Benin,BEN,36.44,4.9,Low income
#
# Burkina Faso,BFA,40.551,9.1,Low income
#
# Bangladesh,BGD,20.142,6.63,Lower middle income
#
# Bulgaria,BGR,9.2,53.0615,Upper middle income
#
# Bahrain,BHR,15.04,90.0000397,High income
#
# "Bahamas, The",BHS,15.339,72,High income
#
# Bosnia and Herzegovina,BIH,9.062,57.79,Upper middle income
#
# ...

# %%
# Q5) WAP to extract the line which starts with C

file_path = (r"D:\Study material\DemographicData.csv")
file = open(file_path,mode='r',encoding='utf-8-sig')
from_list=[i for i in file if i.startswith('C')]
# Out:
# ['CountryName,CountryCode,BirthRate,InternetUsers,IncomeGroup\n', 'Central African Republic,CAF,34.076,3.5,Low income\n', 'Canada,CAN,10.9,85.8,High income\n', 'Chile,CHL,13.385,66.5,High income\n', 'China,CHN,12.1,45.8,Upper middle income\n', "Cote d'Ivoire,CIV,37.32,8.4,Lower middle income\n", 'Cameroon,CMR,37.236,6.4,Lower middle income\n', 'Colombia,COL,16.076,51.7,Upper middle income\n', 'Comoros,COM,34.326,6.5,Low income\n', 'Cabo Verde,CPV,21.625,37.5,Lower middle income\n', 'Costa Rica,CRI,15.022,45.96,Upper middle income\n', 'Cuba,CUB,10.4,27.93,Upper middle income\n', 'Cayman Islands,CYM,12.5,74.1,High income\n', 'Cyprus,CYP,11.436,65.4548,High income\n', 'Czech Republic,CZE,10.2,74.1104,High income\n', 'Croatia,HRV,9.4,66.7476,High income\n', 'Cambodia,KHM,24.462,6.8,Low income\n', 'Chad,TCD,45.745,2.3,Low income\n']
# None
